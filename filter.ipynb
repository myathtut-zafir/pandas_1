# %%
import pandas as pd
results=oly_data=pd.read_excel('./data/olympics-data.xlsx',)

# %%
# results.loc[results['height_cm']>215] # filter and show all result
#  results.loc[results['height_cm']>215,['name']] # filter and show name only
# results[results['height_cm']>215][['name']] # filter and show name only
# results[(results['height_cm']>215)&(results['born_country']=="GER")] # add two filters
#string filter
# results[results['name'].str.contains("Keith")] # add string filter
# results[results['name'].str.contains("keith|patrick",case=False)] # add string filter
# results[results['name'].str.contains("keith|patrick",case=False,regex=False)] # no data will be found because we close the regex
# results[results['born_country'].isin(["USA"])] # isin like whereIn
# results[results['born_country'].isin(["USA"]) & (results['name'].str.startswith("Monique"))] # isin and str "and" contadion
# results.query('born_country=="USA" and born_city=="Seattle"') # another way of query
# Out:
#         athlete_id                   name   born_date born_city born_region  \
# 11030        11088          David Halpern  1955-08-18   Seattle  Washington
# 12800        12870            Todd Trewin  1958-04-20   Seattle  Washington
# 15476        15583         Scott McKinley  1968-10-15   Seattle  Washington
# 29079        29293            Joyce Tanac  1950-09-27   Seattle  Washington
# 31135        31371        Bill Kuhlemeier  1908-01-14   Seattle  Washington
# ...            ...                    ...         ...       ...         ...
# 133392      136331          Hans Struzyna  1989-03-31   Seattle  Washington
# 135448      138662  Maude Davis Crossland  2003-03-19   Seattle  Washington
# 136993      140229        Jenell Berhorst  2003-12-13   Seattle  Washington
# 143507      147159         Nevin Harrison  2002-06-02   Seattle  Washington
# 145446      149169       Corinne Stoddard  2001-08-15   Seattle  Washington
#
# ...
